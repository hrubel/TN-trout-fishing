# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %matplotlib inline

# %%
rivers = gpd.read_file('../data/USA_Rivers_and_Streams.geojson')
print(rivers.crs)
rivers.head()
# Out:
# epsg:4326
#    OBJECTID            Name Feature State  Region  Miles  Shape__Length  \
# 0         1                  Stream    AK      19   2.41       0.072752
# 1         2      Bear Creek  Stream    AK      19  24.85       0.525073
# 2         3                  Stream    AK      19   5.67       0.154646
# 3         4                  Stream    AK      19   7.37       0.158399
# 4         5  Fortress Creek  Stream    AK      19  16.18       0.417355
#
#                                             geometry
# 0  LINESTRING (-142.15419 68.53380, -142.15474 68...
# 1  LINESTRING (-159.55596 63.89679, -159.55630 63...
# 2  LINESTRING (-160.40021 63.51687, -160.40115 63...
# 3  LINESTRING (-158.07714 56.65160, -158.07748 56...
# 4  LINESTRING (-153.03977 68.47539, -153.03851 68...

# %%
rivers.Name.value_counts()
# Out:
#                          36725
# Spring Creek               435
# Willow Creek               415
# Bear Creek                 391
# Beaver Creek               389
#                          ...
# Big Skin Bayou               1
# Badland Creek                1
# South Fork Lion Creek        1
# Little Trout Creek           1
# Little Albert Creek          1
# Name: Name, Length: 20543, dtype: int64

# %%
rivers=rivers[rivers['State'].str.contains("TN")]

# %%
rivers.State.value_counts()
# Out:
# TN          1518
# KY-TN         48
# AL-TN         20
# TN-VA         16
# MS-TN         15
# AR-TN         12
# GA-TN         12
# NC-TN         10
# MO-TN          6
# KY-MO-TN       1
# AR-MO-TN       1
# AL-MS-TN       1
# Name: State, dtype: int64

# %%
rivers.plot();
