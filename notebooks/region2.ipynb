# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
response = requests.get("http://www.eregulations.com/tennessee/fishing/region-2/")

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
lakes = soup.find('div', attrs = {'id': "_idContainer055"})

# %%
lakes
# Out:
# <div id="_idContainer055"> <h2><img alt="" src="http://www.eregulations.com/wp-content/uploads/2020/02/TWRA_reservoirs_1_21.jpg"/></h2> <h3>Barkley and Kentucky Lake</h3> <p>See <a href="http://www.eregulations.com/tennessee/fishing/region-1/">Region 1</a>.</p> <h3>Cheatham</h3> <p>Includes Stones River up to J. Percy Priest Dam.</p> <ul> <li><strong>Largemouth/Smallmouth/Spotted Bass:</strong> 5 per day in combination.</li> <li><strong>Largemouth Bass:</strong> 14 inch minimum length limit.</li> <li><strong>Smallmouth Bass:</strong> 18 inch minimum length limit.</li> <li><strong>Spotted Bass:</strong> no length limit.</li> <li><strong>Crappie (all species):</strong> 30 per day in combination, 10 inch minimum length limit.</li> <li><strong>Catfish (all species):</strong> No creel limit for fish 34 inches and less in length; only one fish over 34 inches in length may be harvested per day.</li> <li><strong>Striped Bass or Hybrid Striped Bass:</strong> 2 per day in combination, 15 inch minimum length limit.</li> <li><strong>White Bass:</strong> 15 per day, no length limit.</li> <li><strong>Yellow Bass:</strong> no creel or length limit.</li> <li><strong>Walleye:</strong> 5 per day, 16 inch minimum length limit.</li> <li><strong>Sauger:</strong> 10 per day, 15 inch minimum length limit.</li> <li><strong>Paddlefish:</strong> 2 per day; season is open from April 24 through May 31. <em>Culling is prohibited.</em></li> <li><strong>Rock Bass:</strong> 20 per day, no length limit.</li> <li><strong>Redear Sunfish:</strong> 20 per day, no length limit.</li> <li><strong>Bluegill/Warmouth and other sunfishes:</strong> no creel or length limit.</li> </ul> <h3>Cordell Hull</h3> <p>See <a href="http://www.eregulations.com/tennessee/fishing/region-3/">Region 3</a>.</p> <h3>Normandy</h3> <ul> <li><strong>Largemouth/Smallmouth/Spotted Bass:</strong> 5 per day in combination.</li> <li><strong>Largemouth Bass:</strong> 15 inch minimum length limit.</li> <li><strong>Smallmouth Bass:</strong> 18 inch minimum length limit.</li> <li><strong>Spotted Bass:</strong> no length limit.</li> <li><strong>Crappie (all species):</strong> 15 per day in combination, 10 inch minimum length limit.</li> <li><strong>Catfish (all species):</strong> No creel limit for fish 34 inches and less in length; only one fish over 34 inches in length may be harvested per day.</li> <li><strong>White Bass:</strong> 15 per day, no length limit.</li> <li><strong>Walleye:</strong> 5 per day, 16 inch minimum length limit.</li> <li><strong>Rock Bass:</strong> 20 per day, no length limit.</li> <li><strong>Redear Sunfish:</strong> 20 per day, no length limit.</li> <li><strong>Bluegill/Warmouth and other sunfishes:</strong> no creel or length limit.</li> </ul> <h3>Old Hickory</h3> <ul> <li><strong>Largemouth/Smallmouth/Spotted Bass:</strong> 5 per day in combination.</li> <li><strong>Largemouth Bass:</strong> 14 inch minimum length limit.</li> <li><strong>Smallmouth Bass:</strong> 18 inch minimum length limit.</li> <li><strong>Spotted Bass:</strong> no length limit.</li> <li><strong>Crappie (all species):</strong> 30 per day in combination, 10 inch minimum length limit.</li> <li><strong>Catfish (all species):</strong> No creel limit for fish 34 inches and less in length; only one fish over 34 inches in length may be harvested per day.</li> <li><strong>Striped Bass or Hybrid Striped Bass:</strong> 2 per day in combination, 15 inch minimum length limit.</li> <li><strong>White Bass:</strong> 15 per day, no length limit.</li> <li><strong>Yellow Bass:</strong> no creel or length limit.</li> <li><strong>Walleye:</strong> 5 per day, 16 inch minimum length limit.</li> <li><strong>Sauger:</strong> 10 per day, 15 inch minimum length limit.</li> <li><strong>Paddlefish:</strong> 2 per day; season is open from April 24 through May 31. <em>Culling is prohibited.</em></li> <li><strong>Rock Bass:</strong> 20 per day, no length limit.</li> <li><strong>Redear Sunfish:</strong> 20 per day, no length limit.</ ...

# %%
names=lakes.find_all("h3")

# %%
fish_list=lakes.find_all("ul")

# %%
print(names)
# Out:
# [<h3>Barkley and Kentucky Lake</h3>, <h3>Cheatham</h3>, <h3>Cordell Hull</h3>, <h3>Normandy</h3>, <h3>Old Hickory</h3>, <h3>Percy Priest</h3>, <h3>Tims Ford</h3>, <h3>Woods</h3>]

# %%
results=[]
for i, j in zip(names, fish_list):
    name = i.text
    for fish in j.find_all("li"):
        fish_name = fish.find("strong").text
        fish_desc = fish.text.split(": ")[1]
        results.append([name, fish_name, fish_desc])

# %%
lake = pd.DataFrame(results, columns = ['Name', 'Species','Description'])

# %%
lake.head(50)
# Out:
#                          Name                                 Species  \
# 0   Barkley and Kentucky Lake     Largemouth/Smallmouth/Spotted Bass:
# 1   Barkley and Kentucky Lake                        Largemouth Bass:
# 2   Barkley and Kentucky Lake                        Smallmouth Bass:
# 3   Barkley and Kentucky Lake                           Spotted Bass:
# 4   Barkley and Kentucky Lake                  Crappie (all species):
# 5   Barkley and Kentucky Lake                  Catfish (all species):
# 6   Barkley and Kentucky Lake    Striped Bass or Hybrid Striped Bass:
# 7   Barkley and Kentucky Lake                             White Bass:
# 8   Barkley and Kentucky Lake                            Yellow Bass:
# 9   Barkley and Kentucky Lake                                Walleye:
# 10  Barkley and Kentucky Lake                                 Sauger:
# 11  Barkley and Kentucky Lake                             Paddlefish:
# 12  Barkley and Kentucky Lake                              Rock Bass:
# 13  Barkley and Kentucky Lake                         Redear Sunfish:
# 14  Barkley and Kentucky Lake  Bluegill/Warmouth and other sunfishes:
# 15                   Cheatham     Largemouth/Smallmouth/Spotted Bass:
# 16                   Cheatham                        Largemouth Bass:
# 17                   Cheatham                        Smallmouth Bass:
# 18                   Cheatham                           Spotted Bass:
# 19                   Cheatham                  Crappie (all species):
# 20                   Cheatham                  Catfish (all species):
# 21                   Cheatham                             White Bass:
# 22                   Cheatham                                Walleye:
# 23                   Cheatham                              Rock Bass:
# 24                   Cheatham                         Redear Sunfish:
# 25                   Cheatham  Bluegill/Warmouth and other sunfishes:
# 26               Cordell Hull     Largemouth/Smallmouth/Spotted Bass:
# 27               Cordell Hull                        Largemouth Bass:
# 28               Cordell Hull                        Smallmouth Bass:
# 29               Cordell Hull                           Spotted Bass:
# 30               Cordell Hull                  Crappie (all species):
# 31               Cordell Hull                  Catfish (all species):
# 32               Cordell Hull    Striped Bass or Hybrid Striped Bass:
# 33               Cordell Hull                             White Bass:
# 34               Cordell Hull                            Yellow Bass:
# 35               Cordell Hull                                Walleye:
# 36               Cordell Hull                                 Sauger:
# 37               Cordell Hull                             Paddlefish:
# 38               Cordell Hull                              Rock Bass:
# 39               Cordell Hull                         Redear Sunfish:
# 40               Cordell Hull  Bluegill/Warmouth and other sunfishes:
# 41                   Normandy     Largemouth/Smallmouth/Spotted Bass:
# 42                   Normandy                        Largemouth Bass:
# 43                   Normandy                        Smallmouth Bass:
# 44                   Normandy                           Spotted Bass:
# 45                   Normandy                  Crappie (all species):
# 46                   Normandy                  Catfish (all species):
# 47                   Normandy    Striped Bass or Hybrid Striped Bass:
# 48                   Normandy                             White Bass:
# 49                   Normandy                            Yellow Bass:
#
#                                           Description
# 0                           5 per day in combination.
# 1                       14 inch minimum length limit.
# 2                       18 inch minimum length limit.
# 3                                    no length limit.
# 4   30 per day in combination, 10 inch minimum len...
# 5   No creel limit for fish 34 inches and less in ...
# 6   2 per day in combination, 15 inch minimum leng...
# 7                        15 per day, no length limit.
# 8                           no creel or length limit.
# 9            5 per day, 16 inch minimum length limit.
# 10          10 per day, 15 inch minimum length limit.
# 11  2 per day; season is open from April 24 throug...
# 12                       20 per day, no length limit.
# 13                       20 per day, no length limit.
# 14                          no creel or length limit.
# 15                          5 per day in combination.
# 16                      15 inch minimum length limit.
# 17                      18 inch minimum length limit.
# 18                                   no length limit.
# 19  15 per day in combination, 10 inch minimum len...
# 20  No creel limit for fish 34 inches and less in ...
# 21                       15 per day, no length limit.
# 22           5 per day, 16 inch minimum length limit.
# 23                       20 per day, no length limit.
# 24                       20 per day, no length limit.
# 25                          no creel or length limit.
# 26                          5 per day in combination.
# 27                      14 inch minimum length limit.
# 28                      18 inch minimum length limit.
# 29                                   no length limit.
# 30  30 per day in combination, 10 inch minimum len...
# 31  No creel limit for fish 34 inches and less in ...
# 32  2 per day in combination, 15 inch minimum leng...
# 33                       15 per day, no length limit.
# 34                          no creel or length limit.
# 35           5 per day, 16 inch minimum length limit.
# 36          10 per day, 15 inch minimum length limit.
# 37  2 per day; season is open from April 24 throug...
# 38                       20 per day, no length limit.
# 39                       20 per day, no length limit.
# 40                          no creel or length limit.
# 41                          5 per day in combination.
# 42                      15 inch minimum length limit.
# 43                            18 inch minimum length.
# 44                                   no length limit.
# 45  30 per day in combination, 10 inch minimum len...
# 46  No creel limit for fish 34 inches and less in ...
# 47  2 per day in combination, 15 inch minimum leng...
# 48                       15 per day, no length limit.
# 49                          no creel or length limit.

# %%
lake["Region"]= "2"

# %%
lake.head()
# Out:
#                         Name                              Species  \
# 0  Barkley and Kentucky Lake  Largemouth/Smallmouth/Spotted Bass:
# 1  Barkley and Kentucky Lake                     Largemouth Bass:
# 2  Barkley and Kentucky Lake                     Smallmouth Bass:
# 3  Barkley and Kentucky Lake                        Spotted Bass:
# 4  Barkley and Kentucky Lake               Crappie (all species):
#
#                                          Description Region
# 0                          5 per day in combination.      2
# 1                      14 inch minimum length limit.      2
# 2                      18 inch minimum length limit.      2
# 3                                   no length limit.      2
# 4  30 per day in combination, 10 inch minimum len...      2

# %%
lake.Species.value_counts()
# Out:
# Crappie (all species):                    6
# White Bass:                               6
# Bluegill/Warmouth and other sunfishes:    6
# Largemouth/Smallmouth/Spotted Bass:       6
# Redear Sunfish:                           6
# Rock Bass:                                6
# Catfish (all species):                    6
# Smallmouth Bass:                          6
# Yellow Bass:                              5
# Spotted Bass:                             5
# Largemouth Bass:                          5
# Walleye:                                  4
# Striped Bass or Hybrid Striped Bass:      4
# Paddlefish:                               2
# Sauger:                                   2
# Largemouth/Spotted Bass:                  1
# Name: Species, dtype: int64

# %%
lake.to_csv("../data/region2_water.csv")
